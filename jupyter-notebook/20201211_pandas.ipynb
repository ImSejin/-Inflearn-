# %% [markdown]
# # Numpy, Pandas, Matplotlib 실습

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = np.random.rand(25)
data
# Out:
# array([0.30758511, 0.40792876, 0.28749879, 0.73536331, 0.03968164,
#        0.26600181, 0.10820232, 0.41965084, 0.73771685, 0.52895441,
#        0.2754356 , 0.14430315, 0.87447951, 0.58296969, 0.64855935,
#        0.77900112, 0.78333448, 0.88715683, 0.27762664, 0.50339424,
#        0.06494052, 0.17505183, 0.90140588, 0.6586901 , 0.58813173])

# %%
series = pd.Series(data)
series
# Out:
# 0     0.307585
# 1     0.407929
# 2     0.287499
# 3     0.735363
# 4     0.039682
# 5     0.266002
# 6     0.108202
# 7     0.419651
# 8     0.737717
# 9     0.528954
# 10    0.275436
# 11    0.144303
# 12    0.874480
# 13    0.582970
# 14    0.648559
# 15    0.779001
# 16    0.783334
# 17    0.887157
# 18    0.277627
# 19    0.503394
# 20    0.064941
# 21    0.175052
# 22    0.901406
# 23    0.658690
# 24    0.588132
# dtype: float64

# %%
series.plot()
# Out:
# <AxesSubplot:>

# %%
plt.show()
