# %% [markdown]
# # Numpy, Pandas, Matplotlib 실습

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = np.random.rand(25)
data
# Out:
# array([0.49144123, 0.55082794, 0.04644883, 0.69770847, 0.46088186,
#        0.72587241, 0.85720757, 0.26108863, 0.57561208, 0.12056788,
#        0.85762555, 0.90522617, 0.52197617, 0.78997027, 0.86713378,
#        0.96001062, 0.43565994, 0.16362028, 0.54415307, 0.81802116,
#        0.92024543, 0.67694827, 0.0807589 , 0.51271595, 0.77076658])

# %%
series = pd.Series(data)
series
# Out:
# 0     0.491441
# 1     0.550828
# 2     0.046449
# 3     0.697708
# 4     0.460882
# 5     0.725872
# 6     0.857208
# 7     0.261089
# 8     0.575612
# 9     0.120568
# 10    0.857626
# 11    0.905226
# 12    0.521976
# 13    0.789970
# 14    0.867134
# 15    0.960011
# 16    0.435660
# 17    0.163620
# 18    0.544153
# 19    0.818021
# 20    0.920245
# 21    0.676948
# 22    0.080759
# 23    0.512716
# 24    0.770767
# dtype: float64

# %%
series.plot()
# Out:
# <AxesSubplot:>

# %%
plt.show()
